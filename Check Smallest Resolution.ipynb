# %%
import os
import cv2

# %%
# Define the base directory containing subdirectories for each class
base_dir = "workspace/images"

# List all subdirectories (each representing a class)
class_directories = [
    os.path.join(base_dir, d)
    for d in os.listdir(base_dir)
    if os.path.isdir(os.path.join(base_dir, d))
]

# Initialize minimum resolution to a large value
min_resolution = float("inf")
min_resolution_image = ""
min_resolution_dims = (0, 0)  # (height, width)

# Iterate over each class directory
for class_dir in class_directories:
    # Get a list of all image file paths in the current class directory
    image_files = [
        os.path.join(class_dir, f)
        for f in os.listdir(class_dir)
        if os.path.isfile(os.path.join(class_dir, f))
    ]

    # Iterate over each image file
    # Define the base directory containing subdirectories for each class
base_dir = "workspace/images"

# List all subdirectories (each representing a class)
class_directories = [
    os.path.join(base_dir, d)
    for d in os.listdir(base_dir)
    if os.path.isdir(os.path.join(base_dir, d))
]

# Initialize minimum resolution to a large value
min_resolution = float("inf")
min_resolution_image = ""
min_resolution_dims = (0, 0)  # (height, width)

# Iterate over each class directory
for class_dir in class_directories:
    # Get a list of all image file paths in the current class directory
    image_files = [
        os.path.join(class_dir, f)
        for f in os.listdir(class_dir)
        if os.path.isfile(os.path.join(class_dir, f))
    ]

    # Iterate over each image file
    for image_file in image_files:
        # Load the image using OpenCV
        img = cv2.imread(image_file)
        
        # Check if the image was loaded successfully
        if img is not None:
            # Calculate the resolution of the image
            resolution = img.shape[0] * img.shape[1]  # height * width
            
            # If the resolution of the current image is smaller than the current minimum,
            # update the minimum resolution and the corresponding image file
            if resolution < min_resolution:
                min_resolution = resolution
                min_resolution_image = image_file
                min_resolution_dims = img.shape[:2]  # (height, width)
        else:
            # Print a warning if the image failed to load
            print(f"Warning: Unable to load image file '{image_file}'")

# Print the image file with the smallest resolution, its resolution, and its dimensions
print(
    f"The image file with the smallest resolution is {min_resolution_image} with a resolution of {min_resolution} and dimensions {min_resolution_dims}."
)
# Out:
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_0.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_1.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_10.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_11.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_12.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_13.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_14.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_2.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_3.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_4.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_5.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_6.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_7.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_8.xml'
# Warning: Unable to load image file 'workspace/images\anorganik\anorganik_9.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_0.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_1.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_10.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_11.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_12.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_13.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_14.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_2.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_3.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_4.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_5.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_6.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_7.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_8.xml'
# Warning: Unable to load image file 'workspace/images\botol_kaca\botol_kaca_9.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_0.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_1.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_10.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_11.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_12.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_13.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_14.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_2.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_3.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_4.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_5.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_6.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_7.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_8.xml'
# Warning: Unable to load image file 'workspace/images\botol_plastik\botol_plastik_9.xml'
# The image file with the smallest resolution is workspace/images\botol_plastik\botol_plastik_1.jpg with a resolution of 172800 and dimensions (480, 360).
